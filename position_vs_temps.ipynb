# %%
import numpy as np
import pylab as pl

# %%
# données
x = [0, 1.2, 3.5, 9.2, 15.4, 24.8, 36.7]
t = [0, 1, 2 ,3, 4, 5, 6]

# incertitude
yerr = 2

# régression polynomiale
p = np.polyfit(t, x, 2)

# affichage des résultats
print('position initiale', p[2], "m") 
print('vitesse initiale', p[1], "m/s") 
print('accéleration', p[0]*2, "m/s^2") 

# graphique
pl.errorbar(t, x, yerr=yerr, ls='', marker='+')
pl.plot(t, np.polyval(p, t))
pl.xlabel('t (s)')
pl.ylabel('x (m)')
pl.title('Position en fonction du temps')
pl.grid()
# Out:
# position initiale 0.2000000000000132 m
# vitesse initiale -0.38571428571429683 m/s
# accéleration 2.142857142857146 m/s^2
